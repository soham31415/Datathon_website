# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up data generators for train and test data
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dir = '/kaggle/input/brain-tumor-mri-images-huge/brain tumor MRI images/train'
test_dir = '/kaggle/input/brain-tumor-mri-images-huge/brain tumor MRI images/val'

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation')

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    validation_data=validation_generator,
                    epochs=10)

# Evaluate the model on test data
test_loss, test_acc = model.evaluate(test_generator)
print('Test accuracy:', test_acc)
# Out:
# Found 14719 images belonging to 3 classes.
# Found 3679 images belonging to 3 classes.
# Found 828 images belonging to 3 classes.
# Epoch 1/10
# 460/460 [==============================] - 613s 1s/step - loss: 0.5997 - accuracy: 0.7470 - val_loss: 0.7567 - val_accuracy: 0.6420
# Epoch 2/10
# 460/460 [==============================] - 606s 1s/step - loss: 0.3482 - accuracy: 0.8571 - val_loss: 0.6730 - val_accuracy: 0.7170
# Epoch 3/10
# 460/460 [==============================] - 607s 1s/step - loss: 0.2180 - accuracy: 0.9152 - val_loss: 0.8553 - val_accuracy: 0.7339
# Epoch 4/10
# 460/460 [==============================] - 609s 1s/step - loss: 0.1263 - accuracy: 0.9522 - val_loss: 0.9053 - val_accuracy: 0.7575
# Epoch 5/10
# 460/460 [==============================] - 608s 1s/step - loss: 0.0913 - accuracy: 0.9655 - val_loss: 0.9034 - val_accuracy: 0.8027
# Epoch 6/10
# 460/460 [==============================] - 605s 1s/step - loss: 0.0587 - accuracy: 0.9788 - val_loss: 0.9811 - val_accuracy: 0.8054
# Epoch 7/10
# 460/460 [==============================] - 604s 1s/step - loss: 0.0479 - accuracy: 0.9842 - val_loss: 1.3766 - val_accuracy: 0.7459
# Epoch 8/10
# 460/460 [==============================] - 605s 1s/step - loss: 0.0471 - accuracy: 0.9843 - val_loss: 1.4916 - val_accuracy: 0.7747
# Epoch 9/10
# 460/460 [==============================] - 605s 1s/step - loss: 0.0585 - accuracy: 0.9800 - val_loss: 0.8157 - val_accuracy: 0.8062
# Epoch 10/10
# 460/460 [==============================] - 603s 1s/step - loss: 0.0372 - accuracy: 0.9886 - val_loss: 1.1138 - val_accuracy: 0.8027
# 26/26 [==============================] - 9s 357ms/step - loss: 0.9664 - accuracy: 0.8394
# Test accuracy: 0.8393719792366028

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set up data generator for new dataset
new_data_dir = '/kaggle/input/brain-tumor-classification-mri/Training'
new_datagen = ImageDataGenerator(rescale=1./255)

new_generator = new_datagen.flow_from_directory(
    new_data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

# Define the model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model.fit(new_generator,
                    epochs=10)

# Evaluate the model on the new dataset
loss, acc = model.evaluate(new_generator)
print('New dataset accuracy:', acc)
# Out:
# Found 2870 images belonging to 4 classes.
# Epoch 1/10
# 90/90 [==============================] - 112s 1s/step - loss: 1.0188 - accuracy: 0.5631
# Epoch 2/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.5816 - accuracy: 0.7666
# Epoch 3/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.3092 - accuracy: 0.8794
# Epoch 4/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.1709 - accuracy: 0.9436
# Epoch 5/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.1171 - accuracy: 0.9575
# Epoch 6/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.0789 - accuracy: 0.9721
# Epoch 7/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.0438 - accuracy: 0.9850
# Epoch 8/10
# 90/90 [==============================] - 113s 1s/step - loss: 0.0580 - accuracy: 0.9812
# Epoch 9/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.0309 - accuracy: 0.9909
# Epoch 10/10
# 90/90 [==============================] - 112s 1s/step - loss: 0.0229 - accuracy: 0.9927
# 90/90 [==============================] - 32s 354ms/step - loss: 0.0058 - accuracy: 0.9990
# New dataset accuracy: 0.998954713344574

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Load the model
# model = tf.keras.models.load_model('model')

# Load the test data
test_datagen = ImageDataGenerator(rescale=1./255)
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Testing'
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical')

# Evaluate the model on the test data
loss, acc = model.evaluate(test_generator)
print('Test accuracy:', acc)
# Out:
# Found 1311 images belonging to 4 classes.
# 41/41 [==============================] - 14s 349ms/step - loss: 1.3558 - accuracy: 0.8177
# Test accuracy: 0.8176963925361633

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_dir = '/kaggle/input/brain-tumor-mri-dataset/Training'
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(224, 224),
        batch_size=32,
        class_mode='categorical')

# Evaluate the model on the test data
loss, acc = model.evaluate(test_generator)
print('Test accuracy:', acc)
# Out:
# Found 5712 images belonging to 4 classes.
# 179/179 [==============================] - 63s 349ms/step - loss: 0.9824 - accuracy: 0.8559
# Test accuracy: 0.8559173941612244

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen_1 = ImageDataGenerator(rescale=1./255, validation_split=0.2)
test_datagen_1 = ImageDataGenerator(rescale=1./255)

train_dir = '/kaggle/input/brain-tumor-mri-images-huge/brain tumor MRI images/train'
test_dir = '/kaggle/input/brain-tumor-mri-images-huge/brain tumor MRI images/val'

train_generator_1 = train_datagen_1.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='training')

validation_generator_1 = train_datagen_1.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical',
    subset='validation')

test_generator_1 = test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

# Define the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model_1.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train the model
history = model_1.fit(train_generator_1,
                    validation_data=validation_generator_1,
                    epochs=6)

# Evaluate the model on test data
test_loss_1, test_acc_1 = model_1.evaluate(test_generator_1)
print('Test accuracy:', test_acc_1)
# Out:
# Found 14719 images belonging to 3 classes.
# Found 3679 images belonging to 3 classes.
# Found 828 images belonging to 3 classes.
# Epoch 1/6
# 460/460 [==============================] - 667s 1s/step - loss: 0.5780 - accuracy: 0.7584 - val_loss: 0.9679 - val_accuracy: 0.6379
# Epoch 2/6
# 460/460 [==============================] - 666s 1s/step - loss: 0.3479 - accuracy: 0.8572 - val_loss: 0.7203 - val_accuracy: 0.6961
# Epoch 3/6
# 460/460 [==============================] - 657s 1s/step - loss: 0.2128 - accuracy: 0.9153 - val_loss: 0.6890 - val_accuracy: 0.7429
# Epoch 4/6
# 460/460 [==============================] - 656s 1s/step - loss: 0.1387 - accuracy: 0.9461 - val_loss: 0.7098 - val_accuracy: 0.7529
# Epoch 5/6
# 460/460 [==============================] - 701s 2s/step - loss: 0.0838 - accuracy: 0.9687 - val_loss: 0.8206 - val_accuracy: 0.7915
# Epoch 6/6
# 460/460 [==============================] - 653s 1s/step - loss: 0.0657 - accuracy: 0.9759 - val_loss: 0.9120 - val_accuracy: 0.7790
# 26/26 [==============================] - 10s 397ms/step - loss: 0.5763 - accuracy: 0.8563
# Test accuracy: 0.8562802076339722

# %%
new_data_dir = '/kaggle/input/brain-mri/Testing'

# Load the new dataset into memory and preprocess it
new_datagen_2 = ImageDataGenerator(rescale=1./255)

new_generator_2 = new_datagen_2.flow_from_directory(
    new_data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical')

# Evaluate the model on the new dataset
loss, acc = model_1.evaluate(new_generator_2)
print('New dataset accuracy:', acc)
# Out:
# Found 289 images belonging to 3 classes.
# 10/10 [==============================] - 4s 337ms/step - loss: 24.9055 - accuracy: 0.3460
# New dataset accuracy: 0.34602075815200806
